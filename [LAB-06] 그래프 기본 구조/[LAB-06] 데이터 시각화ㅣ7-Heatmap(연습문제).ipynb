# %% [markdown]
# # [LAB-06] 7. Heat Map - 연습문제
#
# ## #01. 준비작업
#
# ### 1. 패키치 참조

# %%
from jussam import load_data
from helpers import *
from pandas import pivot_table
import seaborn as sb
# Out:
# 📦 연세대학교 주영아 교수가 제작한 라이브러리를 사용중입니다.
# 📧 Email(1): j.purplerose@yonsei.ac.kr
# 📧 Email(2): j.purplerose@gmail.com
# 📝 Website: https://juyounga.kr/

# %% [markdown]
# ### 2. 데이터 가져오기

# %%
origin = load_data('traffic_acc')
origin
# Out:
# 📚 2005년 1월 부터 2018년 12월 까지 월별 교통사고의 발생건수,부상자수,사망자수 데이터(인덱스/메타데이터 없음, 출처: 공공데이터포털)
#        년도   월   발생건수  사망자수   부상자수
# 0    2005   1  15494   504  25413
# 1    2005   2  13244   431  21635
# 2    2005   3  16580   477  25550
# 3    2005   4  17817   507  28131
# 4    2005   5  19085   571  29808
# ..    ...  ..    ...   ...    ...
# 163  2018   8  18335   357  27749
# 164  2018   9  18371   348  27751
# 165  2018  10  19738   373  28836
# 166  2018  11  19029   298  28000
# 167  2018  12  18010   323  26463
#
# [168 rows x 5 columns]

# %% [markdown]
# ## #02. 요구사항 해결
#
# ### 1. 데이터 재배치

# %%
df1 = pivot_table(origin, index="년도", columns="월", values="발생건수", aggfunc="mean")
df1
# Out:
# 월           1         2         3         4         5         6         7   \
# 년도
# 2005 15494.000 13244.000 16580.000 17817.000 19085.000 18092.000 18675.000
# 2006 14971.000 14270.000 16767.000 17948.000 19140.000 17435.000 18634.000
# 2007 14914.000 14696.000 18166.000 18055.000 19264.000 18310.000 18037.000
# 2008 14741.000 14176.000 16752.000 17498.000 19515.000 18824.000 19562.000
# 2009 16532.000 15502.000 18224.000 19153.000 20237.000 19249.000 20281.000
# 2010 17124.000 15803.000 17801.000 18386.000 20372.000 18910.000 18965.000
# 2011 16454.000 14208.000 16832.000 18570.000 19414.000 18505.000 19253.000
# 2012 16818.000 16656.000 18255.000 19372.000 19672.000 18854.000 19333.000
# 2013 16016.000 14187.000 17465.000 18031.000 19686.000 18329.000 18441.000
# 2014 15905.000 14061.000 18420.000 18443.000 20314.000 18530.000 19649.000
# 2015 16902.000 14939.000 18616.000 19386.000 20543.000 18649.000 20278.000
# ...

# %% [markdown]
# ### 2. 데이터 시각화

# %%
my_plot.heatmap(df1, palette="PuRd", width=1600, height=1000,
                xlabel="월", ylabel="년도")

# %% [markdown]
# ## 3. 문제 풀이
#
# ### 문제 1
#
# 히트맵에서 매년 공통적으로 색이 가장 옅게(밝게) 나타나, 사고 발생건수가 가장 적은 월은?
#
# - **정답**: 2월
# - **해설**: 히트맵의 색상은 옅을수록 값이 작고 진할수록 값이 큼을 의미한다. 2월 열은 거의 모든 년도에서 가장 옅은 색으로 표시되어 있으며, 발생건수도 13,000 ~ 16,000건대로 다른 달에 비해 일관되게 낮다. 이는 2월의 일수가 28~29일로 다른 달보다 적고, 겨울철 외출·차량 이동량이 감소하는 계절적 요인과 맞물려 사고 건수가 적게 집계되는 것으로 해석할 수 있다.
#
# ### 문제 2
#
# 히트맵 전체 기간(2005년~2018년) 중에서 색이 가장 진하게 나타나 최대 발생건수를 기록한 년-월은?
#
# - **정답**: 2015년 10월 (약 21,587건)
# - **해설**: 히트맵에서 가장 진한 색의 셀은 2015년 10월에 위치하며 21,587건으로 표시되어 있다. 그 다음으로 2010년 10월(21,575건), 2009년 10월(21,440건) 등이 비슷한 수준의 진한 색을 보인다. 즉 전체 기간 중 사고 발생이 가장 빈번했던 시점은 2015년 가을(10월)이었음을 한눈에 확인할 수 있다.
#
# ### 문제 3
#
# 히트맵을 월(가로축) 기준으로 비교했을 때 색이 가장 진하게 나타나, 평균적으로 사고 발생건수가 가장 많은 달은?
#
# - **정답**: 10월
# - **해설**: 10월 열은 대부분의 년도에서 19,000건~21,500건대로 다른 달에 비해 가장 진한 색을 일관되게 보이고 있다. 특히 5월·11월과 함께 가을철에 사고 발생건수가 집중되는 경향이 명확히 나타나며, 야외 활동·단풍 관광·일조량 감소 등 가을철 특유의 통행량 증가가 사고 위험을 높이는 것으로 해석할 수 있다.
