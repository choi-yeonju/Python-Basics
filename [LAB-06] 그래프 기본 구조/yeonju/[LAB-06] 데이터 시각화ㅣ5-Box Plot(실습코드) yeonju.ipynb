# %% [markdown]
# # [LAB 06] 데이터 시각화 - 5. Box Plot

# %% [markdown]
# ## #01. 준비작업

# %% [markdown]
# ### 1. 라이브러리 참조

# %%
from jussam import load_data
from helpers import * 
import seaborn as sb
import numpy as np
# Out:
# 📦 연세대학교 주영아 교수가 제작한 라이브러리를 사용중입니다.
# 📧 Email(1): j.purplerose@yonsei.ac.kr
# 📧 Email(2): j.purplerose@gmail.com
# 📝 Website: https://juyounga.kr/

# %% [markdown]
# ### 2. 데이터 가져오기

# %%
origin = load_data('employee_data_40')
origin.head()
# Out:
# 📚 어느 기업의 직원 40명을 대상으로 성별과 결혼상태, 나이, 최종학력, 월수입을 조사한 가상의 데이터(인덱스, 메타데이터 없음)
#    성별 결혼상태  나이 최종학력  월수입
# 0  남자   기혼  21  대학교   60
# 1  남자   기혼  22  대학원  100
# 2  남자   기혼  33  대학교  200
# 3  여자   미혼  33  대학교  120
# 4  남자   미혼  28  대학교   70

# %% [markdown]
# ## #02. BoxPlot 시각화

# %% [markdown]
# ### 1. 자동 인식 패턴

# %%
# 그래프 초기화 
fig, ax = my_plot.init(width=400, height=150)

# 그래프 그리기 
sb.boxplot(data=origin['월수입'], orient="h") 
ax.set_xlabel("월수입", fontsize=7)

# 출력 
my_plot.show()

# %% [markdown]
# ### 2. 자동인식 패턴에 DataFrame 지정을 위한 데이터 전처리

# %%
df = origin[['월수입', '나이']]
df.head()
# Out:
#    월수입  나이
# 0   60  21
# 1  100  22
# 2  200  33
# 3  120  33
# 4   70  28

# %% [markdown]
# ### 3. 자동인식 패턴에 DataFrame 지정하여 상자그림 시각화

# %%
# 그래프 초기화 
fig, ax = my_plot.init(width=640, height=320)

# 그래프 그리기 
sb.boxplot(data=df,orient="v")

# 출력 
my_plot.show()

# %% [markdown]
# ### 4. 개별 데이터 직접 지정 패턴

# %%
# 그래프 초기화 
fig, ax = my_plot.init(width=400, height=150)

# 그래프 그리기 
# -> 데이터가 x축으로 전개되므로 가로 방향 그래프가 된다. 
sb.boxplot(x=df['월수입'])
ax.set_xlabel("월수입", fontsize=7)

# 출력 
my_plot.show()

# %% [markdown]
# ### 5. 데이터 프레임 + 컬럼명 패턴

# %%
# 그래프 초기화 
fig, ax = my_plot.init(width=200, height=300)

# 그래프 그리기 
sb.boxplot(data=origin, y='나이')
ax.set_ylabel("나이", fontsize=7)

# 출력 
my_plot.show()

# %% [markdown]
# ### 6. 범주(hue) 지정

# %%
# 그래프 초기화 
fig, ax = my_plot.init(width=500, height=300)

# 그래프 그리기 
sb.boxplot(data=origin, y='월수입', hue='성별')
ax.set_ylabel("월수입", fontsize=7)

# 출력 
my_plot.show()

# %% [markdown]
# ## #05. 모듈화 기능 확인

# %% [markdown]
# ### 1. 세로 상자 그림

# %%
my_plot.boxplot(data=origin, y='월수입', ylabel="월수입(만원)", width=250,height=300)

# %% [markdown]
# ### 2. 가로 상자 그림

# %%
my_plot.boxplot(data=origin, x='월수입', xlabel="월수입(만원)", width=400, height=200)

# %% [markdown]
# ### 3. 자동설정 (세로 상자그림)

# %%
my_plot.boxplot(data=origin, width=500, height=300)

# %% [markdown]
# ### 4. 자동 설정( 가로 상자 그림)

# %%
my_plot.boxplot(data=origin, orient="h", width=500,height=300)

# %% [markdown]
# ### 5. 범주에 따른 구분

# %%
my_plot.boxplot(data=origin, y='월수입', hue='성별', width=500, height=300, palette="GnBu")

# %% [markdown]
# ## #01. 연습문제

# %%
from jussam import load_data
from helpers import * 
import seaborn as sb
import numpy as np

# %%
origin = load_data('kings_life')
origin.head()
# Out:
# 📚 조선시대 역대 왕의 수명을 조사한 데이터 (출처: 방송통신대학교 통계학개론 수업내용에서 발췌)
#     왕  수명
# 0  태조  73
# 1  정종  62
# 2  태종  45
# 3  세종  53
# 4  문종  38

# %%
# 그래프 초기화 
fig, ax = my_plot.init(width=400, height=150)

# 그래프 그리기 
# -> 데이터가 x축으로 전개되므로 가로 방향 그래프가 된다. 
sb.boxplot(x=origin['수명'])
ax.set_xlabel("수명", fontsize=7)

# 출력 
my_plot.show()

# %%
my_plot.boxplot(data=origin, x='수명', xlabel="수명(세)", width=500, height=200)

# %% [markdown]
# ## #02. 연습문제

# %%
# stock 데이터셋 

# 외국기업 / 내국기업 
# 그림상자

# %%
from jussam import load_data
from helpers import * 
import seaborn as sb
import numpy as np

# %%
origin = load_data('stock')
origin.head()
# Out:
# 📚 상장된 금융사 중 외국기업(F)과 내국기업(K)의 주가 데이터 (출처: 방송통신대학교 통계학개론 수업내용에서 발췌)
#   구분   주가
# 0  F  120
# 1  K  165
# 2  K  147
# 3  F  144
# 4  K  135

# %%
my_plot.boxplot(data=origin, y='주가', ylabel="주가", hue='구분', width=300, height=300)

# %%
df1 = origin[origin['구분'] =='F']
df1
# Out:
#    구분   주가
# 0   F  120
# 3   F  144
# 9   F  147
# 10  F  235
# 11  F  161
# 12  F  139
# 13  F  150
# 14  F  157
# 16  F  139
# 17  F  150
# 18  F  157
# 20  F  163

# %%
# 그래프 초기화 
fig, ax = my_plot.init(width=400, height=150)

# 그래프 그리기 
# -> 데이터가 x축으로 전개되므로 가로 방향 그래프가 된다. 
sb.boxplot(x=df1['주가'])
ax.set_xlabel("주가", fontsize=7)

# 출력 
my_plot.show()

# %%
df2 = origin[origin['구분'] =='K']
df2
# Out:
#    구분   주가
# 1   K  165
# 2   K  147
# 4   K  135
# 5   K  161
# 6   K  102
# 7   K  165
# 8   K  170
# 15  K  173
# 19  K  173
# 21  K  145
# 22  K  129
# 23  K  145

# %%
# 그래프 초기화 
fig, ax = my_plot.init(width=400, height=150)

# 그래프 그리기 
# -> 데이터가 x축으로 전개되므로 가로 방향 그래프가 된다. 
sb.boxplot(x=df2['주가'])
ax.set_xlabel("주가", fontsize=7)

# 출력 
my_plot.show()

# %% [markdown]
# ## #03. 연습문제

# %%
from jussam import load_data
from helpers import * 
import seaborn as sb
import numpy as np

# %%
origin = load_data('grape')
origin.head()
# Out:
# 📚 포도농장에서 수집한 비료 종류에 따른 수확량 자료 (출처: 방송통신대학교 통계학개론 수업내용에서 발췌)
#   비료종류    수확량
# 0    A 39.300
# 1    B 11.400
# 2    A 26.600
# 3    A 23.700
# 4    B 25.800

# %%
my_plot.boxplot(data=origin, y='수확량', ylabel="수확량", hue='비료종류', width=300, height=300)

# %%
df1 = origin[origin['비료종류'] =='A']
df1
# Out:
#    비료종류    수확량
# 0     A 39.300
# 2     A 26.600
# 3     A 23.700
# 5     A 28.500
# 6     A 24.200
# 7     A 17.900
# 10    A 24.300

# %%
# 그래프 초기화 
fig, ax = my_plot.init(width=400, height=150)

# 그래프 그리기 
# -> 데이터가 x축으로 전개되므로 가로 방향 그래프가 된다. 
sb.boxplot(x=df1['수확량'])
ax.set_xlabel("수확량", fontsize=7)

# 출력 
my_plot.show()

# %%
from jussam import load_data
from helpers import * 
import seaborn as sb
import numpy as np

# %%
origin = load_data('stock')
origin.head()
# Out:
# 📚 상장된 금융사 중 외국기업(F)과 내국기업(K)의 주가 데이터 (출처: 방송통신대학교 통계학개론 수업내용에서 발췌)
#   구분   주가
# 0  F  120
# 1  K  165
# 2  K  147
# 3  F  144
# 4  K  135

# %%
df1 = origin[origin['구분'] =='F']
df1
# Out:
#    구분   주가
# 0   F  120
# 3   F  144
# 9   F  147
# 10  F  235
# 11  F  161
# 12  F  139
# 13  F  150
# 14  F  157
# 16  F  139
# 17  F  150
# 18  F  157
# 20  F  163

# %%
# 그래프 초기화 
fig, ax = my_plot.init(width=400, height=150)

# 그래프 그리기 
# -> 데이터가 x축으로 전개되므로 가로 방향 그래프가 된다. 
sb.boxplot(x=df1['주가'])
ax.set_xlabel("주가", fontsize=7)

# 출력 
my_plot.show()

# %% [markdown]
# ## #04. 연습문제

# %%
origin = load_data('analysis_grade')
origin.head()
# Out:
# 📚 통계학개론을 수강하는 두 학과(A, C)의 성적분포 데이터의 일부 (출처: 방송통신대학교 통계학개론 수업내용에서 발췌)
#   학과  점수
# 0  C  54
# 1  A  52
# 2  A  37
# 3  C  41
# 4  A  67

# %%
my_plot.boxplot(data=origin, y='점수', ylabel="점수", hue='학과', width=300, height=300)
