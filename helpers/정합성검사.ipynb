# %%
# my_logit - 불일치 6개 함수 · 14곳 - 대강 됨 
# my_ols - 불일치 2개 함수 · 2곳 - 수정 중 
# my_plot - 불일치 15개 함수 · 19곳
# my_prep -불일치 4개 함수 · 6곳
# my_qtcheck -불일치 0개 함수 · 0곳 - 없다고 나옴 
# my_stats -불일치 2개 함수 · 9곳 - 대강 됨

# %%
# !pip install --upgrade jussam

# %%
import os
print(os.getcwd())
os.listdir()  # 현재 폴더에 my_los.py가 있는지 확인
# Out:
# c:\py_temp\15_LAB\helpers
# ['fonts',
#  'fonts.zip',
#  'KakaoTalk_20260806_154227189.mp4',
#  'my_logit.py',
#  'my_ols.py',
#  'my_plot.py',
#  'my_prep.py',
#  'my_qtcheck.py',
#  'my_stats.py',
#  'my_ts.py',
#  '__init__.py',
#  '__pycache__',
#  '정합성검사.ipynb']

# %%
from jussam import diff, make_api_docs

# %%
make_api_docs(".", "../메뉴얼")
# Out:
# [준비] 모듈 7개: my_logit, my_ols, my_plot, my_prep, my_qtcheck, my_stats, my_ts
# [빌드] 문서를 생성하는 중입니다...
# [완료] 문서가 생성되었습니다: C:\py_temp\15_LAB\메뉴얼
#        C:\py_temp\15_LAB\메뉴얼\index.html 파일을 브라우저로 열어보세요.
# <a href="file:///C:/py_temp/15_LAB/%EB%A9%94%EB%89%B4%EC%96%BC/index.html" target="_blank">📄 생성된 API 문서 열기 (index.html)</a>
# 'C:\\py_temp\\15_LAB\\메뉴얼\\index.html'

# %%
# make_api_docs("./helpers", "./메뉴얼")

# %%
diff("my_logit", "my_logit.py")
# Out:
#  |          | 0/4
# ...

# %%
diff("my_ols", "my_ols.py")
# Out:
#  |          | 0/4
# ...

# %%
diff("my_plot", "my_plot.py")
# Out:
#  |          | 0/4
# ...

# %%
diff("my_prep", "my_prep.py")
# Out:
#  |          | 0/4
# ...

# %%
diff("my_qtcheck", "my_qtcheck.py")
# Out:
#  |          | 0/4
# ...

# %%
diff("my_stats", "my_stats.py")
# Out:
#  |          | 0/4
# ...

# %%
# diff("my_ts", "my_ts.py") 

# "my_ts"라는 이름의 원본 모듈 자체가 등록돼 있지 않아서 나는 겁니다.
# load_fingerprint 함수가 대조할 원본(지문) 파일을 찾으려고 하는데, 현재 등록된 모듈 목록에 다음 8개만 있습니다:
# my_logit, my_ols, my_pipeline, my_plot, my_prep, my_qtcheck, my_stats, my_util

# %%
from jussam import load_data
from helpers import *

# %%
from jussam import *

# %%
import sys
print(sys.version)
# Out:
# 3.14.7 (tags/v3.14.7:823f032, Aug  5 2026, 10:51:32) [MSC v.1944 64 bit (AMD64)]
