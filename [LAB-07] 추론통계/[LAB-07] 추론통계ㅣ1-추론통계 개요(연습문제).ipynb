# %% [markdown]
# # [LAB-07] 1. 추론통계 개요 - 연습문제
#
# ## #01. 준비작업
#
# ### 1. 라이브러리 참조

# %%
from jussam import load_data
from helpers import *
from pandas import melt, DataFrame
# Out:
# 📦 연세대학교 주영아 교수가 제작한 라이브러리를 사용중입니다.
# 📧 Email(1): j.purplerose@yonsei.ac.kr
# 📧 Email(2): j.purplerose@gmail.com
# 📝 Website: https://juyounga.kr/

# %% [markdown]
# ### 2. 데이터 가져오기

# %%
origin = load_data('ad_sales')
origin.head()
# Out:
# 📚 어느 회사의 월별 광고액과 매출액을 조사한 가상의 데이터
#     월  광고비(백만원)  매출액(억원)
# 0  1월         2      100
# 1  2월       142     1690
# 2  3월       122      298
# 3  4월       130      390
# 4  5월       185      590

# %% [markdown]
# ## #02. 요구사항 처리

# %% [markdown]
# ### 1. 시각화를 위한 데이터 재배치

# %%
df = melt(origin, id_vars='월', var_name='구분', value_name='금액')
df.head()
# Out:
#     월        구분   금액
# 0  1월  광고비(백만원)    2
# 1  2월  광고비(백만원)  142
# 2  3월  광고비(백만원)  122
# 3  4월  광고비(백만원)  130
# 4  5월  광고비(백만원)  185

# %% [markdown]
# ### 2. 범주별 신뢰구간 확인

# %%
my_plot.kdeplot(df, '금액', hue='구분', meanline=True, clevel=0.95)

# %% [markdown]
# ## 문제 풀이
#
# ### 문제 1.
#
# 본부장에게 보고할 월평균 광고비(백만원)의 95% 신뢰구간을 구하세요. 구간의 하한값과 상한값은 각각 얼마입니까?
#
# #### 정답
#
# ```
# 하한값 ≈ **107.596** 백만원, 상한값 ≈ **187.071** 백만원
# ```
#
# ### 문제 2.
#
# 같은 방식으로 월평균 매출액(억원)의 95% 신뢰구간을 구하세요. 하한값과 상한값은 각각 얼마입니까?
#
# #### 정답
#
# ```
# 하한값 ≈ **265.736** 억원, 상한값 ≈ **810.597** 억원
# ```
#
# ### 문제 3.
#
# 광고비와 매출액 분포를 하나의 그래프에 함께 시각화 하세요. 그래프를 통해 표시되는 표본평균은 각각 얼마입니까? (이를 위해 데이터를 long 형식으로 재배치 해야 합니다.)
#
#
# #### 정답
#
# ```
# 광고비 평균 ≈ **147.33** 백만원, 매출액 평균 ≈ **538.17** 억원
# ```
