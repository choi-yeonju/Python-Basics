# %% [markdown]
# #  [LAB 07] 추론통계 - 9. 상관분석의 이해

# %% [markdown]
# ## #01. 준비작업

# %% [markdown]
# ### 1. 라이브러리 참조

# %%
from jussam import load_data
from helpers import *
from pandas import DataFrame

import numpy as np
from scipy.stats import pearsonr, spearmanr
# Out:
# 📦 연세대학교 주영아 교수가 제작한 라이브러리를 사용중입니다.
# 📧 Email(1): j.purplerose@yonsei.ac.kr
# 📧 Email(2): j.purplerose@gmail.com
# 📝 Website: https://juyounga.kr/

# %% [markdown]
# ### 2. 데이터 가져오기

# %%
origin = load_data('language_math_scores')
origin.head()
# Out:
# 📚 어느 학급의 언어영역과 수리영역 점수를 기록한 가상의 데이터 셋
#    언어영역  수리영역
# 0    66    66
# 1    58    70
# 2    73    74
# 3    52    58
# 4    72    79

# %% [markdown]
# ## #02. 시각화를 통한 상관정도 확인

# %% [markdown]
# ### 1. 산점도 그래프 시각화

# %%
my_plot.lmplot(origin, x='언어영역', y='수리영역')

# %% [markdown]
# ## #03. 공분산

# %% [markdown]
# ### 공분산 행렬 구하기

# %%
c = np.cov(origin['언어영역'], origin['수리영역'])
c
# Out:
# array([[76.86693878, 54.39020408],
#        [54.39020408, 85.57714286]])

# %% [markdown]
# ## #04. 상관분석

# %% [markdown]
# ### 1. 피어슨 상관계수

# %%
pearson_r , pearson_p = pearsonr(origin["언어영역"], origin["수리영역"])    
print(f"Pearson correlation coefficient: {pearson_r:.4f}, p-value: {pearson_p:.4f}")
# Out:
# Pearson correlation coefficient: 0.6706, p-value: 0.0000

# %% [markdown]
# ### 2. 스피어만 상관계수

# %%
spearman_r , pearman_p = spearmanr(origin["언어영역"], 
                                  origin["수리영역"])    
print(f"Pearman correlation coefficient: {spearman_r:.4f}, p-value: {pearman_p:.4f}")
# Out:
# Pearman correlation coefficient: 0.5991, p-value: 0.0000

# %% [markdown]
# ### 3. 상관행렬

# %%
# 분석 대상 변수명 정의 (이후 셀에서 공통으로 사용) 
xname = '언어영역'
yname = '수리영역'

# method = 'pearson' or 'spearman' 
corr_matrix= origin[[xname, yname]].corr(method='pearson')
corr_matrix
# Out:
#       언어영역  수리영역
# 언어영역 1.000 0.671
# 수리영역 0.671 1.000

# %% [markdown]
# ### 4. 상관계수 히트맵

# %%
my_plot.heatmap(corr_matrix, width=400, height=300, 
                palette='Reds', annot=True, fmt=".3f")

# %% [markdown]
# ### 5. 상관행렬에 직접 배경색상 적용

# %%
corr_matrix.style.background_gradient(cmap='Reds')
# Out:
# <style type="text/css">
# #T_4c009_row0_col0, #T_4c009_row1_col1 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_4c009_row0_col1, #T_4c009_row1_col0 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# </style>
# <table id="T_4c009">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4c009_level0_col0" class="col_heading level0 col0" >언어영역</th>
#       <th id="T_4c009_level0_col1" class="col_heading level0 col1" >수리영역</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4c009_level0_row0" class="row_heading level0 row0" >언어영역</th>
#       <td id="T_4c009_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_4c009_row0_col1" class="data row0 col1" >0.670613</td>
#     </tr>
#     <tr>
#       <th id="T_4c009_level0_row1" class="row_heading level0 row1" >수리영역</th>
#       <td id="T_4c009_row1_col0" class="data row1 col0" >0.670613</td>
# ...
