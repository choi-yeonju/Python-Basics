# %% [markdown]
# ## #01. 준비작업

# %% [markdown]
# ### 1. 라이브러리 참조

# %%
# 라이브러리 기본 참조 
from jussam import load_data
from helpers import *
from IPython.display import display, Markdown

# %% [markdown]
# ### 2. 데이터 가져오기

# %%
origin = load_data('cars')
origin.head()
# Out:
# 📚 자동차의 속도(speed)에 따른 제동거리(dist) 조사 데이터 (출처: R 기본 데이터)
#    speed  dist
# 0      4     2
# 1      4    10
# 2      7     4
# 3      7    22
# 4      8    16

# %% [markdown]
# ### 3. 단순선형회귀

# %%
fit = my_ols.fit_model(origin, 'dist', summary=True)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   dist   R-squared:                       0.651
# Model:                            OLS   Adj. R-squared:                  0.644
# Method:                 Least Squares   F-statistic:                     89.57
# Date:                Thu, 23 Jul 2026   Prob (F-statistic):           1.49e-12
# Time:                        18:05:49   Log-Likelihood:                -206.58
# No. Observations:                  50   AIC:                             417.2
# Df Residuals:                      48   BIC:                             421.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        -17.5791      6.758     -2.601      0.012     -31.168      -3.990
# speed          3.9324      0.416      9.464      0.000       3.097       4.768
# ==============================================================================
# Omnibus:                        8.975   Durbin-Watson:                   1.676
# Prob(Omnibus):                  0.011   Jarque-Bera (JB):                8.189
# Skew:                           0.885   Prob(JB):                       0.0167
# Kurtosis:                       3.893   Cond. No.                         50.7
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ## #02. 모듈화 기능 확인

# %% [markdown]
# ### 1. 회귀분석 결과 보고의 일괄 처리

# %%
# 회귀계수 표 
vdf = my_ols.report_variables(fit, origin)
display(vdf)

# 모형적합도 보고 (로그변환 없음)
display(Markdown(my_ols.report_fitness(fit)))

# 독립변수 보고 (로그변환 없음)
display(Markdown(my_ols.report_variables_text(fit)))
# Out:
#    종속변수   독립변수     B    베타     t  유의확률    공차   VIF
# 0  dist  speed 3.932 0.807 9.464 0.000 1.000 1.000
# **Note. n = 50. F(1, 48) = 89.57, p < 0.001, R^2 = 0.651, Adj.R^2 = 0.644, Durbin-Watson = 1.676**
#
# dist를 종속변수로, speed(을)를 독립변수로한 단순선형회귀분석 결과, 모형은 통계적으로 유의하였다..
#
# > F(1, 48) = 89.57, p < 0.001, R^2 = 0.651.
#
# 즉, speed는 dist의 약 65.11%를 설명하는 것으로 나타났다.
# - **speed**의 회귀계수는 **B = 3.93**으로 나타났으며, 이는 **dist**에 유의한 요인임을 의미한다. (** t(48) = 9.46**, **p < .001**)즉, speed가 **1증가**할 때 dist는 평균적으로 **3.93 증가**하는  것으로 해석된다.

# %% [markdown]
# ## #01. 연습문제

# %%
from jussam import load_data
from helpers import *
from IPython.display import Markdown, display
import pandas as pd

# %%
origin = load_data("father-son")
origin.head()
# Out:
# 📚 아버지와 아들의 키를 조사한 데이터 (출처: https://www.kaggle.com/datasets/aungdev/pearson-dataset-heights-of-fathers-and-their-sons)
#    fheight  sheight
# 0   65.049   59.778
# 1   63.251   63.214
# 2   64.955   63.342
# 3   65.752   62.792
# 4   61.137   64.281

# %%
# 회귀모형 적합
fit = my_ols.fit_model(origin, 'fheight')

# %%
# 회귀계수 표 
vdf = my_ols.report_variables(fit, origin)
display(vdf)

# 모형적합도 보고 (로그변환 없음)
display(Markdown(my_ols.report_fitness(fit)))

# 독립변수 보고 (로그변환 없음)
display(Markdown(my_ols.report_variables_text(fit)))
# Out:
#       종속변수     독립변수     B    베타      t  유의확률    공차   VIF
# 0  fheight  sheight 0.489 0.501 19.006 0.000 1.000 1.000
# **Note. n = 1078. F(1, 1076) = 361.23, p < 0.001, R^2 = 0.251, Adj.R^2 = 0.251, Durbin-Watson = 1.101**
#
# fheight를 종속변수로, sheight(을)를 독립변수로한 단순선형회귀분석 결과, 모형은 통계적으로 유의하였다..
#
# > F(1, 1076) = 361.23, p < 0.001, R^2 = 0.251.
#
# 즉, sheight는 fheight의 약 25.13%를 설명하는 것으로 나타났다.
# - **sheight**의 회귀계수는 **B = 0.49**으로 나타났으며, 이는 **fheight**에 유의한 요인임을 의미한다. (** t(1076) = 19.01**, **p < .001**)즉, sheight가 **1증가**할 때 fheight는 평균적으로 **0.49 증가**하는  것으로 해석된다.

# %% [markdown]
# ## #문제 2

# %% [markdown]
# `salary` 데이터셋은 어느 회사 직원들의 **근속 년수(YearsExperience)** 와 **연봉(Salary)** 을 조사한 자료입니다.
#
# 이 회사 인사팀에 입사한 당신은 근속 년수에 따른 연봉 테이블을 만들기 위해, **추론통계 기반 탐색적 데이터분석 → 단순선형회귀 모델 적합 → 회귀분석의 가정 점검 → 결과 보고**로 이어지는 전 과정을 수행해야 합니다.
#
# ### 데이터 가져오기

# %%
from jussam import load_data
from helpers import *
from IPython.display import Markdown, display
import pandas as pd

# %%
df = load_data("salary")
df.head()
# Out:
# 📚 경력(년차)에 따른 연봉(USD) 데이터 (출처: https://www.kaggle.com/datasets/abhishek14398/salary-dataset-simple-linear-regression)
#
#     field            description
# --  ---------------  -------------
#  0  YearsExperience  경력(년차)
#  1  Salary           연봉(USD)
#    YearsExperience    Salary
# 0            1.200 39344.000
# 1            1.400 46206.000
# 2            1.600 37732.000
# 3            2.100 43526.000
# 4            2.300 39892.000

# %% [markdown]
# ### Q1. `salary` 데이터의 두 변수(`YearsExperience`, `Salary`)에 대해 **결측치 · 이상치 존재 여부**와 **로그 변환 필요 여부**를 판단하시오.

# %%
# 결측치 점검 
display(my_qtcheck.check_missing_values(df))

# 기술통계 + 이상치 / 왜도 / 로그변환 판단 
my_qtcheck.numerical_summary(df).T
# Out:
#                  Missing Count  Missing Ratio (%)
# YearsExperience              0              0.000
# Salary                       0              0.000
#                      YearsExperience       Salary
# count                         30.000       30.000
# mean                           5.413    76004.000
# std                            2.838    27414.430
# min                            1.200    37732.000
# 25%                            3.300    56721.750
# 50%                            4.800    65238.000
# 75%                            7.800   100545.750
# max                           10.600   122392.000
# rel_diff                       0.128        0.165
# rdiff_flag                      diff         diff
# iqr                            4.500    43824.000
# upper_bound                   14.550   166281.750
# lower_bound                   -3.450    -9014.250
# upper_outliers                     0            0
# upper_outliers_ratio           0.000        0.000
# lower_outliers                     0            0
# lower_outliers_ratio           0.000        0.000
# outliers                           0            0
# outliers_ratio                 0.000        0.000
# skew                           0.380        0.354
# skew_interpret             symmetric    symmetric
# kurt                          -1.012       -1.295
# kurt_interpret           platykurtic  platykurtic
# log_need                        none         none

# %% [markdown]
# > **정답 (Q1)** — 결측치 **0개** · IQR 이상치 **0개** · **로그 변환 불필요**(두 변수 모두 |왜도| < 1, `log_need = none`)

# %% [markdown]
# ### Q2. 근속년수와 연봉의 상관분석을 수행했을때 자동으로 선택되는 상관계수의 종류, 값, 그리고 선택이유와 유의성을 답하시오.

# %%
my_stats.correlation(df, x="YearsExperience", y="Salary").T
# Out:
# x                   YearsExperience
# y                            Salary
# method                     Spearman
# coef                          0.957
# p-value                       0.000
# strength                     Strong
# normality_x                    True
# normality_y                   False
# linearity                      True
# influential_outlier           False
# high_skew                     False

# %% [markdown]
# 정답(Q2) - Spearman p ~~ 0.957 (유의, 강한 양의 상관).
# Salary가 정규성을 만족하지 않아 Pearson 대신 선택

# %% [markdown]
# ### Q3. `Salary`를 종속변수, `YearsExperience`를 독립변수로 하는 **단순선형회귀식**을 절편과 기울기를 포함하여 도출하시오.

# %%
# 단순선형회귀 
fit = my_ols.fit_model(df, 'Salary', summary=True)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 Salary   R-squared:                       0.957
# Model:                            OLS   Adj. R-squared:                  0.955
# Method:                 Least Squares   F-statistic:                     622.5
# Date:                Thu, 23 Jul 2026   Prob (F-statistic):           1.14e-20
# Time:                        18:05:50   Log-Likelihood:                -301.44
# No. Observations:                  30   AIC:                             606.9
# Df Residuals:                      28   BIC:                             609.7
# Df Model:                           1
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# const            2.485e+04   2306.654     10.772      0.000    2.01e+04    2.96e+04
# YearsExperience  9449.9623    378.755     24.950      0.000    8674.119    1.02e+04
# ==============================================================================
# Omnibus:                        2.140   Durbin-Watson:                   1.648
# Prob(Omnibus):                  0.343   Jarque-Bera (JB):                1.569
# Skew:                           0.363   Prob(JB):                        0.456
# Kurtosis:                       2.147   Cond. No.                         13.6
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# > **정답 (Q3)** — **Salary = 24,848.20 + 9,449.96 × YearsExperience**

# %% [markdown]
# ### Q4. 이 모형의 **결정계수(R²)** 값과 그 의미, 그리고 **모형의 통계적 유의성**을 답하시오.

# %%
Markdown(my_ols.report_fitness(fit))
# Out:
# **Note. n = 30. F(1, 28) = 622.51, p < 0.001, R^2 = 0.957, Adj.R^2 = 0.955, Durbin-Watson = 1.648**
#
# Salary를 종속변수로, YearsExperience(을)를 독립변수로한 단순선형회귀분석 결과, 모형은 통계적으로 유의하였다..
#
# > F(1, 28) = 622.51, p < 0.001, R^2 = 0.957.
#
# 즉, YearsExperience는 Salary의 약 95.7%를 설명하는 것으로 나타났다.

# %%
my_ols.report_variables(fit, df)
# Out:
#      종속변수             독립변수        B    베타      t  유의확률    공차   VIF
# 0  Salary  YearsExperience 9449.962 0.978 24.950 0.000 1.000 1.000

# %%
new_data = pd.DataFrame({"YearsExperience": [3, 5, 7, 10]})
my_ols.predict(fit, new_data)
# Out:
#         pred
# 0  53198.091
# 1  72098.016
# 2  90997.940
# 3 119347.827

# %%
my_ols.test_linear(fit)
# Out:
#               statistic  p-value  linearity                    result
# Ramsey RESET      0.012    0.915       True  귀무가설 채택 -> 선형성 위배 근거 없음

# %%
my_ols.test_linear(fit)
# Out:
#               statistic  p-value  linearity                    result
# Ramsey RESET      0.012    0.915       True  귀무가설 채택 -> 선형성 위배 근거 없음

# %%
my_ols.test_normal(fit)
# Out:
#                     statistic  p-value  normality             result
# kolmogorov-Smirnov      0.083    0.974       True  귀무가설 채택 -> 정규성 만족

# %%
my_ols.test_equalvar(fit)
# Out:
#                LM statistic  LM p-value  F statistic  F p-value  \
# Breusch-Pagan         0.399       0.528        0.378      0.544
#
#                homoscedasticity              result
# Breusch-Pagan              True  귀무가설 채택 -> 등분산성 만족

# %%
my_ols.test_independent(fit)
# Out:
#                statistic  independence  result
# Durbin-Watson      1.648          True  독립성 만족
